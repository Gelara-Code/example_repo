# %% [markdown]
# # Exercise #3
#
# In this assignment, you'll exercise your SQL query skills.
#
# ## The scenario
#
# In the year 20XX, I have won the lottery and decided to leave my programming days behind me in order to pursue my true calling as a [cat café](https://en.wikipedia.org/wiki/Cat_caf%C3%A9) tycoon. I've stored information about my cats and cafés in [this SQLite database](catcafes.db), which you should download and put in the same directory as this file.
#
# The following cell loads the JupySQL extension and the cat cafés database:

# %%
# !pip3 uninstall ipython-sql -y
# !pip3 install jupysql
# !pip3 install matplotlib pandas
# Out:
# WARNING: Skipping ipython-sql as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupysql in /Users/gelara/Library/Python/3.9/lib/python/site-packages (0.11.1)
# Requirement already satisfied: prettytable>=3.12.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (3.16.0)
# Requirement already satisfied: jinja2 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: sqlglot>=11.3.7 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (30.6.0)
# Requirement already satisfied: ploomber-core>=0.2.7 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: sqlparse in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: sqlalchemy in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (2.0.49)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: pyyaml in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from ploomber-core>=0.2.7->jupysql) (6.9.3)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.15.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: wcwidth in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from prettytable>=3.12.0->jupysql) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from jinja2->jupysql) (3.0.3)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 7.8 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 15.2 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 19.0 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.2-cp39-cp39-macosx_10_9_universal2.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 22.9 MB/s eta 0:00:01
# Collecting numpy>=1.23
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 22.1 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 6.4 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from matplotlib) (26.1)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 18.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 18.3 MB/s eta 0:00:01
# Requirement already satisfied: tzdata>=2022.7 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from pandas) (2026.1)
# Collecting pytz>=2020.1
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 13.8 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/gelara/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: numpy, pytz, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, pandas, matplotlib
#   WARNING: The scripts f2py and numpy-config are installed in '/Users/gelara/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/Users/gelara/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.2 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 numpy-2.0.2 pandas-2.3.3 pillow-11.3.0 pyparsing-3.3.2 pytz-2026.1.post1
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !ls -la ~/Downloads/*.db
# Out:
# -rw-r--r--  1 gelara  staff      0 Apr 20 17:06 /Users/gelara/Downloads/cat_cafe.db
# -rw-r--r--@ 1 gelara  staff  16384 Apr 20 17:06 /Users/gelara/Downloads/catcafes.db
# -rw-r--r--  1 gelara  staff      0 Apr 20 16:43 /Users/gelara/Downloads/your_database.db

# %%
# !mv "/Users/gelara/Downloads/catcafes .db" /Users/gelara/Downloads/catcafes.db
# Out:
# mv: /Users/gelara/Downloads/catcafes .db: No such file or directory

# %%
# %load_ext sql
# %sql sqlite:////Users/gelara/Downloads/catcafes.db
# %sqlcmd tables
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# +----------+
# |   Name   |
# +----------+
# |   cafe   |
# |   cat    |
# | cat_cafe |
# +----------+

# %% [markdown]
# Because I'm focused on taking care of cats and scouting out new café locations, I need some help querying the database. And that's what you're going to do in this notebook! Let's take a look at the structure of the database.
#
# There are three tables:

# %%
# %load_ext sql
# %sql sqlite:////Users/gelara/Downloads/catcafes.db
# %sqlcmd tables
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# +----------+
# |   Name   |
# +----------+
# |   cafe   |
# |   cat    |
# | cat_cafe |
# +----------+

# %% [markdown]
# The `cafe` table lists all of the cafés in my growing cat café empire. Each café has a name, a ZIP code, and a unique ID number:

# %%
# %sqlcmd columns -t cafe
# Out:
# +---------+-------------+----------+---------+-------------+
# |   name  |     type    | nullable | default | primary_key |
# +---------+-------------+----------+---------+-------------+
# |    id   |   INTEGER   |   True   |   None  |      1      |
# |   name  | VARCHAR(40) |   True   |   None  |      0      |
# | zipcode |  VARCHAR(5) |   True   |   None  |      0      |
# +---------+-------------+----------+---------+-------------+

# %% [markdown]
# The `cat` table contains information about every cat who currently lives in one of my cafés. Each cat has a unique ID, a name, its weight in pounds, its fur color, and the pattern of the fur. If you're interested, [read more on the interesting topic of cat coat genetics](https://en.wikipedia.org/wiki/Cat_coat_genetics).

# %%
# %sqlcmd columns -t cat
# Out:
# +---------+----------------+----------+---------+-------------+
# |   name  |      type      | nullable | default | primary_key |
# +---------+----------------+----------+---------+-------------+
# |    id   |    INTEGER     |   True   |   None  |      1      |
# |   name  |  VARCHAR(40)   |   True   |   None  |      0      |
# |  weight | NUMERIC(10, 2) |   True   |   None  |      0      |
# |  color  |  VARCHAR(40)   |   True   |   None  |      0      |
# | pattern |  VARCHAR(40)   |   True   |   None  |      0      |
# +---------+----------------+----------+---------+-------------+

# %% [markdown]
# Finally, there is a linking table called `cat_cafe` which associates cats to cafés. Each café has a number of cats, and some cats are moved regularly between locations. Thus there is a many-to-many relationship between cats and cafés. The `active` field indicates the cat's current location.

# %%
# %sqlcmd columns -t cat_cafe
# Out:
# +---------+---------+----------+---------+-------------+
# |   name  |   type  | nullable | default | primary_key |
# +---------+---------+----------+---------+-------------+
# |  cat_id | INTEGER |   True   |   None  |      0      |
# | cafe_id | INTEGER |   True   |   None  |      0      |
# |  active | BOOLEAN |   True   |   None  |      0      |
# +---------+---------+----------+---------+-------------+

# %% [markdown]
# Thank you for helping out!

# %% [markdown]
# ## Task 1: Columns and equals
#
# Modify the query below so that the query returns the names of all tabby cats.
#
# Expected output:
#
# |    name   |
# | --------- |
# |  Georges  |
# |  Scaredy  |
# | Charlotte |
# |   Minka   |
# |   Carlos  |
# |   Chanel  |
# |    Jiji   |

# %%
# %%sql
# SELECT name
# FROM cat
# WHERE pattern = 'tabby'
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-----------+
# |    name   |
# +-----------+
# |  Georges  |
# |  Scaredy  |
# | Charlotte |
# |   Minka   |
# |   Carlos  |
# |   Chanel  |
# |    Jiji   |
# +-----------+

# %% [markdown]
# ## Task 2: Order and limits
#
# Modify the query below so that it returns the name and zipcode of the cafe whose name comes last in alphabetical order.
#
# Expected output:
#
# |    name    | zipcode |
# |:----------:|:-------:|
# | Tall Tails |  11222  |

# %%
# %%sql
# SELECT name, zipcode
# FROM cafe
# ORDER BY name DESC
# LIMIT 1
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +------------+---------+
# |    name    | zipcode |
# +------------+---------+
# | Tall Tails |  11222  |
# +------------+---------+

# %% [markdown]
# ## Task 3: Inequality expressions
#
# Modify the query below so that it returns the names of all cats whose coloring is either white or black, and who weight more than 9 lbs, listed in alphabetical order by name.
#
# Expected output:
#
# |    name   |
# | --------- |
# |   Charly  |
# |  Georges  |
# |    Jack   |
# |    Jiji   |
# | Lafayette |
# |    Mimi   |
# | Sylvester |
# |  Whiskers |

# %%
# %%sql
# SELECT name
# FROM cat
# WHERE weight > 9 AND (color = 'white' OR color = 'black')
# ORDER BY name
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-----------+
# |    name   |
# +-----------+
# |   Charly  |
# |  Georges  |
# |    Jack   |
# |    Jiji   |
# | Lafayette |
# |    Mimi   |
# | Sylvester |
# |  Whiskers |
# +-----------+

# %% [markdown]
# ## Task 4: Aggregation and grouping
#
# Modify the SQL statement below so that it returns a list of cat colors along with the weight of the heaviest cat having that color. Only show colors whose heaviest cat weighs more than 10.5 lbs.
#
# Expected output:
#
# |  color   | max(weight) |
# | -------- | ----------- |
# |  brown   |    10.88    |
# | cinnamon |    11.37    |
# |  lilac   |    10.76    |
# |   red    |      12     |

# %%
# %%sql
# SELECT color, max(weight)
# FROM cat
# GROUP BY color
# HAVING max(weight) > 10.5
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +----------+-------------+
# |  color   | max(weight) |
# +----------+-------------+
# |  brown   |    10.88    |
# | cinnamon |    11.37    |
# |  lilac   |    10.76    |
# |   red    |      12     |
# +----------+-------------+

# %% [markdown]
# ## Task 5: Joins, part 1
#
# Modify the query below so that it shows the name of every tortoiseshell cat along with the `id` field of the café where the cat can currently be found (i.e., the `active` field is true).
#
# Expected output:
#
# |    name   | cafe_id |
# | --------- | ------- |
# |    Luna   |    2    |
# |   Angel   |    4    |
# |   Moritz  |    2    |
# |  O'Malley |    3    |
# | Lafayette |    5    |

# %%
# %%sql
# SELECT cat.name, cat_cafe.cafe_id
# FROM cat
# JOIN cat_cafe ON cat.id = cat_cafe.cat_id
# WHERE cat.pattern = 'tortoiseshell' AND cat_cafe.active = true
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-----------+---------+
# |    name   | cafe_id |
# +-----------+---------+
# |    Luna   |    2    |
# |   Angel   |    4    |
# |   Moritz  |    2    |
# |  O'Malley |    3    |
# | Lafayette |    5    |
# +-----------+---------+

# %% [markdown]
# ## Task 6: Joins, part 2
#
# The following query is just like the one above, except it shows the name of the café instead of its ID. Add the additional `JOIN` to make the query work.
#
# Expected output:
#
# |    name   |       name_1      |
# | --------- | ----------------- |
# |    Luna   | Independent Claws |
# |   Angel   |     Tall Tails    |
# |   Moritz  | Independent Claws |
# |  O'Malley |   Paws and Play   |
# | Lafayette |     Cats Meow     |

# %%
# %%sql
# SELECT cat.name, cafe.name
# FROM cat
# JOIN cat_cafe ON cat.id = cat_cafe.cat_id
# JOIN cafe ON cafe.id = cat_cafe.cafe_id
# WHERE cat.pattern = 'tortoiseshell' AND cat_cafe.active = true
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-----------+-------------------+
# |    name   |       name_1      |
# +-----------+-------------------+
# |    Luna   | Independent Claws |
# |   Angel   |     Tall Tails    |
# |   Moritz  | Independent Claws |
# |  O'Malley |   Paws and Play   |
# | Lafayette |     Cats Meow     |
# +-----------+-------------------+

# %% [markdown]
# ## Task 7: Joins with DISTINCT
#
# Quick, I need to know which zip codes have lilac tabby cats! Fix the query below to give me this information.
#
# Expected output:
#
# | zipcode |
# | ------- |
# |  11215  |
# |  11237  |

# %%
# %%sql
# SELECT DISTINCT(cafe.zipcode)
# FROM cat
# JOIN cat_cafe ON cat.id = cat_cafe.cat_id
# JOIN cafe ON cafe.id = cat_cafe.cafe_id
# WHERE cat.color = 'lilac' AND cat.pattern = 'tabby' AND cat_cafe.active = true
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +---------+
# | zipcode |
# +---------+
# |  11215  |
# |  11237  |
# +---------+

# %% [markdown]
# ## Task 8 (advanced): Joins with aggregation
#
# Okay, time to take off the training wheels. Modify the query below so that it returns the name of each café along with the average weight of all of the cats at that location.
#
# Expected output:
#
# |        name       |  avg(cat.weight)  |
# | ----------------- | ----------------- |
# |     Cats Meow     | 9.754999999999999 |
# |   Hang In There   | 9.254285714285714 |
# | Independent Claws | 9.334545454545456 |
# |   Paws and Play   | 9.284545454545453 |
# |     Tall Tails    | 9.817142857142857 |

# %%
# %%sql
# SELECT cafe.name, avg(cat.weight)
# FROM cafe
# JOIN cat_cafe ON cafe.id = cat_cafe.cafe_id
# JOIN cat ON cat.id = cat_cafe.cat_id
# WHERE cat_cafe.active = true
# GROUP BY cafe.name
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-------------------+-------------------+
# |        name       |  avg(cat.weight)  |
# +-------------------+-------------------+
# |     Cats Meow     | 9.754999999999999 |
# |   Hang In There   | 9.254285714285714 |
# | Independent Claws | 9.334545454545456 |
# |   Paws and Play   | 9.284545454545453 |
# |     Tall Tails    | 9.817142857142857 |
# +-------------------+-------------------+

# %% [markdown]
# ## Task 9 (advanced): Joins with order and limit
#
# Write a query below that returns the name of the café with the most tortoiseshell cats, along with the number of tortoiseshell cats at that location.
#
# Expected output:
#
# |        name       | count(cat.name) |
# | ----------------- | --------------- |
# | Independent Claws |        2        |

# %%
# %%sql
# SELECT cafe.name, count(cat.name)
# FROM cafe
# JOIN cat_cafe ON cafe.id = cat_cafe.cafe_id
# JOIN cat ON cat.id = cat_cafe.cat_id
# WHERE cat.pattern = 'tortoiseshell' AND cat_cafe.active = true
# GROUP BY cafe.name
# ORDER BY count(cat.name) DESC
# LIMIT 1
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'
# +-------------------+-----------------+
# |        name       | count(cat.name) |
# +-------------------+-----------------+
# | Independent Claws |        2        |
# +-------------------+-----------------+

# %% [markdown]
# ## Task 10 (advanced): Pandas integration
#
# Write code in the cell below to show a histogram of cat weights with eight bins. Do this by assigning the result of the query to a variable and fetching the Pandas dataframe.
#
# Expected output:
#
# <img src="data:image/png;base64,...">

# %%
import matplotlib.pyplot as plt

result = %sql SELECT weight FROM cat
df = result.DataFrame()
df['weight'].plot(kind='hist', bins=8)
plt.xlabel('weight')
plt.show()
# Out:
# Running query in 'sqlite:////Users/gelara/Downloads/catcafes.db'

# %% [markdown]
# Great work! You're hired.
